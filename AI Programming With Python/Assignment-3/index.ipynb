# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data set Install

# %%
# Load the dataset
data = pd.read_csv('../data/titanic_data_updated.csv')

# %%
# Display the first few rows of the dataset
data.head()

# %%
data.info()

# %%
data.isnull().sum()
